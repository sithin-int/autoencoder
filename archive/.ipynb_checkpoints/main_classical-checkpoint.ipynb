# %%
'''
1. Change in the choice of the estimator associated with the feature selection method (merged sequence only)

Estimators - LR, SVM, RF, XGBoost, ANN (for each estimator, change the optimization metric)

2. Change in the choice of the optimization metric (merged sequence only) - Brier score, roc_auc, prauc, f1

3. Change in the minority class distribution (merged sequence only) - 5, 15, 25, 30

4. Change in the order of the sequence being integrated - merged v/s per-sequence

5. Applying AE selected features on predictive modelling - LR, SVM, RF, XGBoost, ANN, Autoencoder (Bier score, roc auc, prauc) (for merged sequence, hyperparameter tuning)

'''

# %% [markdown]
# ### 1. Reading and Processing the stable radiomic features

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

import numpy as np

# %%
OUT_PATH=r"./results"
FEAT_PATH = r"./features_StudySettings3D.csv"
INT_ICC_PATH = r"./stability_study_results/INT_Clinical/inout_plane_systematic_features_StudySettings3D.csv"
EXT_ICC_PATH = r"./stability_study_results/QIN_NonClinical_Dependent/inout_plane_systematic_features_StudySettings3D.csv"

SEQUENCE_BESTFILTER_PREFIX = {
    
                "t2w":["original_shape","logarithm_firstorder","logarithm_glcm","logarithm_glszm","logarithm_glrlm","logarithm_gldm","logarithm_ngtdm"],
               
                "adc":["original_shape","log-sigma-5-0-mm-3D_firstorder","square_glcm","exponential_glszm","exponential_glrlm","exponential_gldm","exponential_ngtdm"],
                
                "dce_win":["original_shape","logarithm_firstorder","logarithm_glcm","wavelet-HLL_glszm","logarithm_glrlm","square_gldm","logarithm_ngtdm"],
                
                "dce_wout":["original_shape","logarithm_firstorder","logarithm_glcm","logarithm_glszm","logarithm_glrlm","logarithm_gldm","logarithm_ngtdm"]
                
               }

ICC_THRESHOLD = 0.90

# %%
feat_df = pd.read_csv(FEAT_PATH)
int_icc_df = pd.read_csv(INT_ICC_PATH, index_col=0)
ext_icc_df = pd.read_csv(EXT_ICC_PATH, index_col=0)

# %%
selected_feats = {}

for i, row_int  in int_icc_df.iterrows():
    
    feature, _, c_down_int, _, sequence = row_int
       
    row_ext = ext_icc_df[ext_icc_df.feature==feature][ext_icc_df.sequence==sequence.split("_")[0]]#this is because for internal set there is dce_win and dce_wout, but for external there is only dce
    
    _, _, c_down_ext, _, _ = row_ext.values[0].tolist()

    if c_down_int>=ICC_THRESHOLD and c_down_ext>=ICC_THRESHOLD:
    
        prefices = SEQUENCE_BESTFILTER_PREFIX[sequence]

        for prefix in prefices:

            if prefix in feature:
                selected_feats.setdefault(sequence,[]).append(feature)
# Out:
# e:\sithin\myenv\lib\site-packages\ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %% [markdown]
# ### 2. Merged Features of all the sequences

# %%
features = []

merged_df = {}

for sequence,feats in selected_feats.items():### 9. Compute Delta based on mean
    
    for feat in feats:
        features.append(sequence+"_"+feat)
        merged_df[sequence+"_"+feat] = feat_df[feat_df.sequence==sequence].sort_values(by=['id'])[feat].values

merged_df["label"] = feat_df[feat_df.sequence==sequence].sort_values(by=['id'])["label"].values
merged_df["id"] = feat_df[feat_df.sequence==sequence].sort_values(by=['id'])["id"].values
    
merged_df = pd.DataFrame.from_dict(merged_df)

# %% [markdown]
# ### 3. Sort Features In an Orderly Way (Pearson correlation is dependent on that, Simple to Complex features)

# %%
def sort_feats(features):

    sorted_features = []

    for sequence in ["t2w","adc","dce_win","dce_wout"]:

        for feat_type in ["shape","firstorder","glcm","glszm","glrlm","gldm","ngtdm"]:

            feats = sorted([feat for feat in features if sequence in feat and feat_type in feat and feat not in sorted_features])

            sorted_features += feats
            
    return sorted_features

# %%
features = sort_feats(features)

len(features)
# Out:
# 321

# %%
merged_df["label"].value_counts()
# Out:
# 0    69
# 1    31
# Name: label, dtype: int64

# %%
merged_df.label.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Removing features with zero variance

# %%
var_threshold = 0.0

# %%
feats,var_tags = zip(*((merged_df[features].var()<=var_threshold).to_dict()).items())
low_variance_features = list(np.array(feats)[np.array(var_tags)])
features = list(set(features) - set(low_variance_features))
print(f"Removed {len(low_variance_features)}; {len(features)} remaining")
# Out:
# Removed 0; 321 remaining

# %%
features = sort_feats(features)

# %% [markdown]
# ### 5. Shape and Volume Correlated Feature Filtering

# %%
R_THRESHOLD = 0.85

# %%
#Removing Features Correlated with Shape which includes volume features as well

to_drop = []
corr = merged_df[features].corr(method="pearson").abs()
corr_dict = corr.to_dict()

for feat in features:

    if "original_shape" in feat:

        _to_drop = [key for key,val in corr_dict[feat].items() if val>=R_THRESHOLD and key not in to_drop]
        to_drop += _to_drop

    
features = list(set(features)-set(to_drop))
print(f"{len(to_drop)} highly shape correlated features deleted, {len(features)} features remaining")
# Out:
# 58 highly shape correlated features deleted, 263 features remaining

# %%
features = sort_feats(features)

# %% [markdown]
# ### 7. Feautre filtering using pearson correlation coefficient on the merged dataframe

# %%
R_THRESHOLD = 0.85

# %%
corr = merged_df[features].corr(method="pearson").abs()#order matters actually here
up_tri = corr.where(np.triu(np.ones(corr.shape),k=1).astype(bool))
to_drop = [column for column in up_tri.columns if any(up_tri[column] >= R_THRESHOLD)]
filtered_features = list(set(features)-set(to_drop))


print(f"{len(to_drop)} highly correlated features deleted, {len(filtered_features)} features remaining")
# Out:
# 197 highly correlated features deleted, 66 features remaining

# %%
filtered_features = sort_feats(filtered_features)

# %% [markdown]
# # Impact of Estimator & Optimization Metric

# %%
from sklearn.feature_selection import SequentialFeatureSelector as SFS
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.pipeline import make_pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier

# %%
#LR, SVM, RF, XGBoost, ANN

# %%
rskf = RepeatedStratifiedKFold(n_splits=3, n_repeats=100,random_state=0)

# %%
metrics = [
    "accuracy",
    "neg_brier_score",
    "roc_auc",
    "f1",
    "average_precision"
]

# %%
estimators = [
    
    LogisticRegression(penalty='none', max_iter=1000),
    DecisionTreeClassifier(),
    SVC(probability=True),
    RandomForestClassifier(),
    GradientBoostingClassifier(),
    MLPClassifier()
]

# %%
def run_bsfs(estimator, filtered_features, metric):
    
    n = len(filtered_features)
    rank_dict = {}
    
    pbar = tqdm(range(n-1),desc=f"Running Backwards SFS with {estimator.__class__.__name__}_{metric}", position=0)
    
    while n>1:
    
        X = merged_df[filtered_features].to_numpy()
        y = merged_df["label"].to_numpy().ravel()

        sfs_pipeline = make_pipeline(StandardScaler(), SFS(estimator, n_features_to_select=n-1, direction='backward', scoring=metric, cv=rskf, n_jobs = 4))
        sfs_pipeline.fit(X,y)
          

        eliminated_feature = np.array(filtered_features)[~sfs_pipeline['sequentialfeatureselector'].support_][0]
        rank_dict[eliminated_feature] = n

        filtered_features = np.array(filtered_features)[sfs_pipeline['sequentialfeatureselector'].support_]

        n -= 1
        
        pbar.update()
    
    rank_dict[filtered_features[0]] = n
        
        
    return rank_dict

# %%
rank_dfs = {}

# %%
for estimator in estimators:
    
    for metric in metrics:
        
        _rank_dict = run_bsfs(estimator, filtered_features, metric)
        _rank_dict = dict(sorted(_rank_dict.items(), key=lambda item: item[1]))
        
        feats, ranks = zip(*_rank_dict.items())

        rank_dict = {"feature":list(feats),"rank":list(ranks)}
        rank_df = pd.DataFrame.from_dict(rank_dict)
        
        rank_dfs[estimator.__class__.__name__+"_"+metric] = rank_df
        
    
    break;
# Out:
# Running Backwards SFS with LogisticRegression_accuracy:   2%|▍                          | 1/65 [00:31<34:04, 31.95s/it]exception calling callback for <Future at 0x1efbdace848 state=finished returned list>
# Traceback (most recent call last):
#   File "e:\sithin\myenv\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "e:\sithin\myenv\lib\site-packages\joblib\_parallel_backends.py", line 556, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x1efbdaee6c8 state=finished returned list>
# Traceback (most recent call last):
#   File "e:\sithin\myenv\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "e:\sithin\myenv\lib\site-packages\joblib\_parallel_backends.py", line 556, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# exception calling callback for <Future at 0x1efbd9b1348 state=finished returned list>
# Traceback (most recent call last):
#   File "e:\sithin\myenv\lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "e:\sithin\myenv\lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "e:\sithin\myenv\lib\site-packages\joblib\_parallel_backends.py", line 556, in apply_async
#     future = self._workers.submit(SafeFunction(func))
# AttributeError: 'NoneType' object has no attribute 'submit'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2976\801252521.py in <module>
#       3     for metric in metrics:
#       4
# ----> 5         _rank_dict = run_bsfs(estimator, filtered_features, metric)
#       6         _rank_dict = dict(sorted(_rank_dict.items(), key=lambda item: item[1]))
#       7
#
# ~\AppData\Local\Temp\ipykernel_2976\2408531877.py in run_bsfs(estimator, filtered_features, metric)
#      12
#      13         sfs_pipeline = make_pipeline(StandardScaler(), SFS(estimator, n_features_to_select=n-1, direction='backward', scoring=metric, cv=rskf, n_jobs = 4))
# ---> 14         sfs_pipeline.fit(X,y)
#      15
#      16
#
# e:\sithin\myenv\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     392             if self._final_estimator != "passthrough":
#     393                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 394                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     395
#     396         return self
#
# e:\sithin\myenv\lib\site-packages\sklearn\feature_selection\_sequential.py in fit(self, X, y)
#     208         for _ in range(n_iterations):
#     209             new_feature_idx = self._get_best_new_feature(
# --> 210                 cloned_estimator, X, y, current_mask
#     211             )
#     212             current_mask[new_feature_idx] = True
#
# e:\sithin\myenv\lib\site-packages\sklearn\feature_selection\_sequential.py in _get_best_new_feature(self, estimator, X, y, current_mask)
#     236                 cv=self.cv,
#     237                 scoring=self.scoring,
# --> 238                 n_jobs=self.n_jobs,
#     239             ).mean()
#     240         return max(scores, key=lambda feature_idx: scores[feature_idx])
#
# e:\sithin\myenv\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     518         fit_params=fit_params,
#     519         pre_dispatch=pre_dispatch,
# --> 520         error_score=error_score,
#     521     )
#     522     return cv_results["test_score"]
#
# e:\sithin\myenv\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     281             error_score=error_score,
#     282         )
# --> 283         for train, test in cv.split(X, y, groups)
#     284     )
#     285
#
# e:\sithin\myenv\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# e:\sithin\myenv\lib\site-packages\joblib\parallel.py in retrieve(self)
#     968             # we empty it and Python list are not thread-safe by default hence
#     969             # the use of the lock
# --> 970             with self._lock:
#     971                 job = self._jobs.pop(0)
#     972
#
# KeyboardInterrupt:

# %%
# Out:
# 'LogisticRegression'

# %%
np.array(filtered_features)[sfs_pipeline['sequentialfeatureselector'].get_support()]
# Out:
# array(['adc_exponential_glszm_ZonePercentage'], dtype='<U60')

# %%
print(sfs_pipeline['sequentialfeatureselector'].features)

print(sfs_pipeline['sequentialfeatureselector'].get_support())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2976\1902817560.py in <module>
# ----> 1 print(sfs_pipeline['sequentialfeatureselector'].features)
#       2
#       3 print(sfs_pipeline['sequentialfeatureselector'].get_support())
#
# AttributeError: 'SequentialFeatureSelector' object has no attribute 'features'
